# %%
import pandas as pd
import numpy as np
import re

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# --------------

# %% [markdown]
# ### Combining the data files into one data frame

# %%
file_name1 = "games_data/lowest_rated_games.csv"
file_name2 = "games_data/top_rated_games.csv"
df = pd.concat(
    map(pd.read_csv, [file_name1, file_name2]), ignore_index=True)

# %% [markdown]
# ## <font color='red'>Problem1:</font> Incomplete data
# See problem: [4_EDA](./4_EDA.ipynb)
#
# Following this problem, which was addressed in the previous step by scraping all the data
#
# We created a new data frame and saved it in 'all_games.csv' file
#
# See previous step: [game_crawling](./2_game_crawling.ipynb) => <font color='red'>'Problem1: Incomplete data'</font>

# %% [markdown]
# And then we will save everything in a new file: [handled_games.csv](#Incomplete_data)

# %%
df = pd.read_csv("games_data/all_games.csv")

# Deletion of the index column - "Unnamed: 0"
df.drop("Unnamed: 0", axis=1, inplace=True)

# %% [markdown]
# # Now we will handle the data in the new file

# %% [markdown]
# <a id='Improving_Performance'></a>
# ## <font color='red'>Problem2:</font> Improving Performance
# See problem: [machine_learning](./5_machine_learning.ipynb)
#
# ## At the machine learning stage we saw that the ability to predict was not the best
# ### f1 = 0.456
#
# ### So we came back here and made some changes:
#
# - [Dropping the nan values for 'user_score' and Not filling the nan values with the mean values](#Improving_Performance1)
# - [Handling Duplicates in 'genres'](#Improving_Performance2)
#
# Finally we saved everything in a new file: [all_games3.csv](#Improving_Performance4)

# %% [markdown]
# --------------
# Checking the data

# %%
df.head()
# Out:
#                               game_name       platform       publisher  \
# 0  The Legend of Zelda: Ocarina of Time    Nintendo 64        Nintendo
# 1              Tony Hawk's Pro Skater 2    PlayStation      Activision
# 2                   Grand Theft Auto IV  PlayStation 3  Rockstar Games
# 3                           SoulCalibur      Dreamcast           Namco
# 4                   Grand Theft Auto IV       Xbox 360  Rockstar Games
#
#    release_date  meta_scroe user_score               develeoper  \
# 0  Nov 23, 1998        99.0        9.1                 Nintendo
# 1  Sep 20, 2000        98.0        7.5  Neversoft Entertainment
# 2  Apr 29, 2008        98.0        7.8           Rockstar North
# 3  Sep  8, 1999        98.0        8.4                    Namco
# 4  Apr 29, 2008        98.0        8.0           Rockstar North
#
#                                          genres num_of_players rating  \
# 0                     Action Adventure, Fantasy       1 Player      E
# 1            Sports, Alternative, Skateboarding            1-2      T
# 2  Action Adventure, Modern, Modern, Open-World       1 Player      M
# 3                          Action, Fighting, 3D            1-2      T
# 4  Action Adventure, Modern, Modern, Open-World       1 Player      M
#
#   user_positive_review user_negative_review user_mixed_review  \
# 0                6,736                  529               270
# 1                  609                  150               112
# 2                3,450                  607               770
# 3                  335                   40                31
# 4                2,687                  451               555
#
#    critic_positive_review  critic_negative_review  critic_mixed_review
# 0                    22.0                     0.0                  0.0
# 1                    19.0                     0.0                  0.0
# 2                    64.0                     0.0                  0.0
# 3                    24.0                     0.0                  0.0
# 4                    86.0                     0.0                  0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19223 entries, 0 to 19222
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_name               19223 non-null  object
#  1   platform                19223 non-null  object
#  2   publisher               19211 non-null  object
#  3   release_date            19223 non-null  object
#  4   meta_scroe              19214 non-null  float64
#  5   user_score              19220 non-null  object
#  6   develeoper              19202 non-null  object
#  7   genres                  19223 non-null  object
#  8   num_of_players          15494 non-null  object
#  9   rating                  17111 non-null  object
#  10  user_positive_review    17950 non-null  object
#  11  user_negative_review    17950 non-null  object
#  12  user_mixed_review       17950 non-null  object
#  13  critic_positive_review  19216 non-null  float64
#  14  critic_negative_review  19216 non-null  float64
#  15  critic_mixed_review     19216 non-null  float64
# dtypes: float64(4), object(12)
# memory usage: 2.3+ MB

# %% [markdown]
# --------------

# %% [markdown]
# ## In user_score there are some 'tbd' values
# 'tbd' = to be declared

# %%
df[df['user_score'] == "tbd"].head()
# Out:
#                                               game_name       platform  \
# 1095              Atari 50: The Anniversary Celebration  Xbox Series X
# 1548  Pinball FX 2: Marvel Pinball - Vengeance and V...       Xbox 360
# 1612                                         NeverAwake             PC
# 1638                              This Way Madness Lies             PC
# 1658                                NASCAR Thunder 2003           Xbox
#
#          publisher  release_date  meta_scroe user_score       develeoper  \
# 1095         Atari  Nov 11, 2022        87.0        tbd  Digital Eclipse
# 1548   Zen Studios  Dec 13, 2011        84.0        tbd      Zen Studios
# 1612   Neotro Inc.  Sep 28, 2022        84.0        tbd      Neotro Inc.
# 1638  Zeboyd Games  Nov 10, 2022        84.0        tbd     Zeboyd Games
# 1658     EA Sports  Sep 19, 2002        84.0        tbd        EA Sports
#
#                                                  genres  \
# 1095                         Miscellaneous, Compilation
# 1548    Pinball, Action, Miscellaneous, Parlor, Pinball
# 1612  Action, General, Shooter, Shoot-'Em-Up, Horizo...
# 1638      Action, General, Role-Playing, Japanese-Style
# 1658                         Driving, Racing, Stock Car
#
#              num_of_players rating user_positive_review user_negative_review  \
# 1095  No Online Multiplayer      T                  NaN                  NaN
# 1548                    NaN      E                  NaN                  NaN
# 1612  No Online Multiplayer    NaN                  NaN                  NaN
# 1638  No Online Multiplayer    NaN                  NaN                  NaN
# 1658                    1-4      E                    2                    0
#
#      user_mixed_review  critic_positive_review  critic_negative_review  \
# 1095               NaN                     9.0                     0.0
# 1548               NaN                     7.0                     0.0
# 1612               NaN                     9.0                     0.0
# 1638               NaN                     6.0                     0.0
# 1658                 0                    12.0                     0.0
#
#       critic_mixed_review
# 1095                  0.0
# 1548                  0.0
# 1612                  0.0
# 1638                  1.0
# 1658                  1.0

# %% [markdown]
# ### Changing the 'tbd' to nan values:

# %%
df.replace("tbd", np.nan, inplace=True)
df[df["user_score"] == "tbd"]
# Out:
# Empty DataFrame
# Columns: [game_name, platform, publisher, release_date, meta_scroe, user_score, develeoper, genres, num_of_players, rating, user_positive_review, user_negative_review, user_mixed_review, critic_positive_review, critic_negative_review, critic_mixed_review]
# Index: []

# %% [markdown]
# --------------
# Checking the data:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19223 entries, 0 to 19222
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_name               19223 non-null  object
#  1   platform                19223 non-null  object
#  2   publisher               19211 non-null  object
#  3   release_date            19223 non-null  object
#  4   meta_scroe              19214 non-null  float64
#  5   user_score              17843 non-null  object
#  6   develeoper              19202 non-null  object
#  7   genres                  19223 non-null  object
#  8   num_of_players          15494 non-null  object
#  9   rating                  17111 non-null  object
#  10  user_positive_review    17950 non-null  object
#  11  user_negative_review    17950 non-null  object
#  12  user_mixed_review       17950 non-null  object
#  13  critic_positive_review  19216 non-null  float64
#  14  critic_negative_review  19216 non-null  float64
#  15  critic_mixed_review     19216 non-null  float64
# dtypes: float64(4), object(12)
# memory usage: 2.3+ MB

# %% [markdown]
# --------------

# %% [markdown]
# ## Dropping the nan values for: 'meta_scroe', 'publisher', 'develeoper':
#
# This information can not be determined and replaced

# %%
df.dropna(subset=['meta_scroe'], inplace=True)
df.dropna(subset=['publisher'], inplace=True)
df.dropna(subset=['develeoper'], inplace=True)

# %% [markdown]
# --------------
# Checking the data:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19183 entries, 0 to 19222
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_name               19183 non-null  object
#  1   platform                19183 non-null  object
#  2   publisher               19183 non-null  object
#  3   release_date            19183 non-null  object
#  4   meta_scroe              19183 non-null  float64
#  5   user_score              17814 non-null  object
#  6   develeoper              19183 non-null  object
#  7   genres                  19183 non-null  object
#  8   num_of_players          15470 non-null  object
#  9   rating                  17091 non-null  object
#  10  user_positive_review    17921 non-null  object
#  11  user_negative_review    17921 non-null  object
#  12  user_mixed_review       17921 non-null  object
#  13  critic_positive_review  19183 non-null  float64
#  14  critic_negative_review  19183 non-null  float64
#  15  critic_mixed_review     19183 non-null  float64
# dtypes: float64(4), object(12)
# memory usage: 2.5+ MB

# %% [markdown]
# --------------

# %%
df[df["user_score"].isnull()]
# Out:
#                                                game_name       platform  \
# 1095               Atari 50: The Anniversary Celebration  Xbox Series X
# 1548   Pinball FX 2: Marvel Pinball - Vengeance and V...       Xbox 360
# 1612                                          NeverAwake             PC
# 1638                               This Way Madness Lies             PC
# 1658                                 NASCAR Thunder 2003           Xbox
# ...                                                  ...            ...
# 19040                                   Sanity of Morris       Xbox One
# 19050                                      King of Clubs            Wii
# 19111                                   Jenga World Tour             DS
# 19126                                   Dream Chronicles  PlayStation 3
# 19128                                  Smash 'N' Survive  PlayStation 3
#
#                    publisher  release_date  meta_scroe user_score  \
# 1095                   Atari  Nov 11, 2022        87.0        NaN
# 1548             Zen Studios  Dec 13, 2011        84.0        NaN
# 1612             Neotro Inc.  Sep 28, 2022        84.0        NaN
# 1638            Zeboyd Games  Nov 10, 2022        84.0        NaN
# 1658               EA Sports  Sep 19, 2002        84.0        NaN
# ...                      ...           ...         ...        ...
# 19040     StickyLock Studios  Mar 23, 2021        35.0        NaN
# 19050                  Crave  Aug  4, 2008        35.0        NaN
# 19111                  Atari  Nov 13, 2007        32.0        NaN
# 19126   Hudson Entertainment  Nov 23, 2010        31.0        NaN
# 19128  Version2Games Limited  Feb 22, 2012        31.0        NaN
#
#                         develeoper  \
# 1095               Digital Eclipse
# 1548                   Zen Studios
# 1612                   Neotro Inc.
# 1638                  Zeboyd Games
# 1658                     EA Sports
# ...                            ...
# 19040               Alterego Games
# 19050           Oxygen Interactive
# 19111  Atomic Planet Entertainment
# 19126                    PlayFirst
# 19128        Version2Games Limited
#
#                                                   genres  \
# 1095                          Miscellaneous, Compilation
# 1548     Pinball, Action, Miscellaneous, Parlor, Pinball
# 1612   Action, General, Shooter, Shoot-'Em-Up, Horizo...
# 1638       Action, General, Role-Playing, Japanese-Style
# 1658                          Driving, Racing, Stock Car
# ...                                                  ...
# 19040                         Action Adventure, Survival
# 19050  Sports, Traditional, Individual, Golf, Arcade,...
# 19111              Miscellaneous, Puzzle, Party, General
# 19126  Miscellaneous, Puzzle, Puzzle, Hidden Object, ...
# 19128                  Driving, Racing, General, General
#
#               num_of_players rating user_positive_review user_negative_review  \
# 1095   No Online Multiplayer      T                  NaN                  NaN
# 1548                     NaN      E                  NaN                  NaN
# 1612   No Online Multiplayer    NaN                  NaN                  NaN
# 1638   No Online Multiplayer    NaN                  NaN                  NaN
# 1658                     1-4      E                    2                    0
# ...                      ...    ...                  ...                  ...
# 19040  No Online Multiplayer    NaN                    0                    0
# 19050  No Online Multiplayer      E                  NaN                  NaN
# 19111              2  Online      E                    2                    1
# 19126                    NaN      E                  NaN                  NaN
# 19128                    NaN    NaN                  NaN                  NaN
#
#       user_mixed_review  critic_positive_review  critic_negative_review  \
# 1095                NaN                     9.0                     0.0
# 1548                NaN                     7.0                     0.0
# 1612                NaN                     9.0                     0.0
# 1638                NaN                     6.0                     0.0
# 1658                  0                    12.0                     0.0
# ...                 ...                     ...                     ...
# 19040                 2                     0.0                     5.0
# 19050               NaN                     1.0                     9.0
# 19111                 0                     0.0                     6.0
# 19126               NaN                     0.0                     6.0
# 19128               NaN                     0.0                    14.0
#
#        critic_mixed_review
# 1095                   0.0
# 1548                   0.0
# 1612                   0.0
# 1638                   1.0
# 1658                   1.0
# ...                    ...
# 19040                  2.0
# 19050                  1.0
# 19111                  1.0
# 19126                  2.0
# 19128                  2.0
#
# [1369 rows x 16 columns]

# %% [markdown]
# <a id='Improving_Performance1'></a>
# ## <font color='red'>Problem2:</font> Not filling the 'user_score' nan values with the mean values
# See problem in page: [Problem2: Improving Performance](#Improving_Performance)
#
# ## Dropping the nan values for 'user_score'
#
# This information can not be determined and replaced

# %%
df["user_score"] = df["user_score"].astype("float64")
df["user_score"].mean()
# Out:
# 6.928544964634617

# %%
df.dropna(subset=['user_score'], inplace=True)
# df["user_score"].fillna(df["user_score"].mean(), inplace=True)

# %% [markdown]
# --------------
# Checking the data:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17814 entries, 0 to 19222
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_name               17814 non-null  object
#  1   platform                17814 non-null  object
#  2   publisher               17814 non-null  object
#  3   release_date            17814 non-null  object
#  4   meta_scroe              17814 non-null  float64
#  5   user_score              17814 non-null  float64
#  6   develeoper              17814 non-null  object
#  7   genres                  17814 non-null  object
#  8   num_of_players          14382 non-null  object
#  9   rating                  15902 non-null  object
#  10  user_positive_review    17253 non-null  object
#  11  user_negative_review    17253 non-null  object
#  12  user_mixed_review       17253 non-null  object
#  13  critic_positive_review  17814 non-null  float64
#  14  critic_negative_review  17814 non-null  float64
#  15  critic_mixed_review     17814 non-null  float64
# dtypes: float64(5), object(11)
# memory usage: 2.3+ MB

# %%
df.describe(include="all")
# Out:
#             game_name platform publisher  release_date    meta_scroe  \
# count           17814    17814     17814         17814  17814.000000
# unique          11695       22      1911          4580           NaN
# top     Madden NFL 07       PC   Ubisoft  Nov 14, 2006           NaN
# freq                9     4816       777            44           NaN
# mean              NaN      NaN       NaN           NaN     70.639329
# std               NaN      NaN       NaN           NaN     12.027933
# min               NaN      NaN       NaN           NaN     11.000000
# 25%               NaN      NaN       NaN           NaN     64.000000
# 50%               NaN      NaN       NaN           NaN     73.000000
# 75%               NaN      NaN       NaN           NaN     79.000000
# max               NaN      NaN       NaN           NaN     99.000000
#
#           user_score develeoper                  genres  \
# count   17814.000000      17814                   17814
# unique           NaN       3702                    2184
# top              NaN     Capcom  Action, Platformer, 2D
# freq             NaN        335                     490
# mean        6.928545        NaN                     NaN
# std         1.359784        NaN                     NaN
# min         0.300000        NaN                     NaN
# 25%         6.300000        NaN                     NaN
# 50%         7.200000        NaN                     NaN
# 75%         7.900000        NaN                     NaN
# max         9.700000        NaN                     NaN
#
#                num_of_players rating user_positive_review  \
# count                   14382  15902                17253
# unique                     56      7                 1168
# top     No Online Multiplayer      T                    4
# freq                     6208   5452                  731
# mean                      NaN    NaN                  NaN
# std                       NaN    NaN                  NaN
# min                       NaN    NaN                  NaN
# 25%                       NaN    NaN                  NaN
# 50%                       NaN    NaN                  NaN
# 75%                       NaN    NaN                  NaN
# max                       NaN    NaN                  NaN
#
#        user_negative_review user_mixed_review  critic_positive_review  \
# count                 17253             17253            17814.000000
# unique                  594               468                     NaN
# top                       2                 2                     NaN
# freq                   1827              1634                     NaN
# mean                    NaN               NaN               13.068036
# std                     NaN               NaN               15.641455
# min                     NaN               NaN                0.000000
# 25%                     NaN               NaN                3.000000
# 50%                     NaN               NaN                8.000000
# 75%                     NaN               NaN               17.000000
# max                     NaN               NaN              140.000000
#
#         critic_negative_review  critic_mixed_review
# count             17814.000000         17814.000000
# unique                     NaN                  NaN
# top                        NaN                  NaN
# freq                       NaN                  NaN
# mean                  1.570001             8.648872
# std                   3.376621             7.781927
# min                   0.000000             0.000000
# 25%                   0.000000             3.000000
# 50%                   0.000000             6.000000
# 75%                   2.000000            12.000000
# max                  51.000000            71.000000

# %% [markdown]
# --------------

# %% [markdown]
# ### Data with large numbers are with commas

# %%
df["user_positive_review"][20]
# Out:
# '6,414'

# %% [markdown]
# Therefore, a simple conversion to the int type will not help here

# %% [markdown]
# # Review Data handling

# %% [markdown]
# ### Conversion of all review data to int type without the commas

# %%
colums = ["user_positive_review", "user_negative_review", "user_mixed_review"]
for column in colums:
    nums = []
    for string in df[column]:
        if(type(string) != float):
            nums.append(int(string.replace(",", "")))
        else:
            nums.append(np.nan)
    df[column] = nums

# %% [markdown]
# --------------
# Checking the data:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17814 entries, 0 to 19222
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_name               17814 non-null  object
#  1   platform                17814 non-null  object
#  2   publisher               17814 non-null  object
#  3   release_date            17814 non-null  object
#  4   meta_scroe              17814 non-null  float64
#  5   user_score              17814 non-null  float64
#  6   develeoper              17814 non-null  object
#  7   genres                  17814 non-null  object
#  8   num_of_players          14382 non-null  object
#  9   rating                  15902 non-null  object
#  10  user_positive_review    17253 non-null  float64
#  11  user_negative_review    17253 non-null  float64
#  12  user_mixed_review       17253 non-null  float64
#  13  critic_positive_review  17814 non-null  float64
#  14  critic_negative_review  17814 non-null  float64
#  15  critic_mixed_review     17814 non-null  float64
# dtypes: float64(8), object(8)
# memory usage: 2.8+ MB

# %% [markdown]
# --------------

# %% [markdown]
# ## Filling the review data nan values with the mean values

# %%
columns = [
    "user_positive_review", "user_negative_review", "user_mixed_review",
    "critic_positive_review", "critic_negative_review", "critic_mixed_review"
]
for column in columns:
    df[column] = df[column].astype("float")
    df[column].fillna(df[column].mean(), inplace=True)

# %% [markdown]
# ## Normalizing the review data

# %%
# making a new normalize column of 'user_positive_review'
user_review = df.iloc[:,10:13].copy()
user_review_sum = user_review["user_positive_review"] + user_review["user_negative_review"] + user_review["user_mixed_review"]
user_review["user_positive_normalize"] = user_review["user_positive_review"] / user_review_sum

df["user_positive_normelize"] = user_review["user_positive_normalize"]

# %%
# making a new normalize column of 'critic_positive_review'
critic_review = df.iloc[:,-4:-1].copy()
critic_review_sum = critic_review["critic_positive_review"] + critic_review["critic_mixed_review"] + critic_review["critic_negative_review"]
critic_review["critic_positive_normalize"] = critic_review["critic_positive_review"] / critic_review_sum

df["critic_positive_normelize"] = critic_review["critic_positive_normalize"]

# %%
df.drop(columns, axis=1, inplace=True)

# %% [markdown]
# --------------
# Checking the data:

# %%
df.head()
# Out:
#                               game_name       platform       publisher  \
# 0  The Legend of Zelda: Ocarina of Time    Nintendo 64        Nintendo
# 1              Tony Hawk's Pro Skater 2    PlayStation      Activision
# 2                   Grand Theft Auto IV  PlayStation 3  Rockstar Games
# 3                           SoulCalibur      Dreamcast           Namco
# 4                   Grand Theft Auto IV       Xbox 360  Rockstar Games
#
#    release_date  meta_scroe  user_score               develeoper  \
# 0  Nov 23, 1998        99.0         9.1                 Nintendo
# 1  Sep 20, 2000        98.0         7.5  Neversoft Entertainment
# 2  Apr 29, 2008        98.0         7.8           Rockstar North
# 3  Sep  8, 1999        98.0         8.4                    Namco
# 4  Apr 29, 2008        98.0         8.0           Rockstar North
#
#                                          genres num_of_players rating  \
# 0                     Action Adventure, Fantasy       1 Player      E
# 1            Sports, Alternative, Skateboarding            1-2      T
# 2  Action Adventure, Modern, Modern, Open-World       1 Player      M
# 3                          Action, Fighting, 3D            1-2      T
# 4  Action Adventure, Modern, Modern, Open-World       1 Player      M
#
#    user_positive_normelize  critic_positive_normelize
# 0                 0.893962                        1.0
# 1                 0.699196                        1.0
# 2                 0.714730                        1.0
# 3                 0.825123                        1.0
# 4                 0.727593                        1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17814 entries, 0 to 19222
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   game_name                  17814 non-null  object
#  1   platform                   17814 non-null  object
#  2   publisher                  17814 non-null  object
#  3   release_date               17814 non-null  object
#  4   meta_scroe                 17814 non-null  float64
#  5   user_score                 17814 non-null  float64
#  6   develeoper                 17814 non-null  object
#  7   genres                     17814 non-null  object
#  8   num_of_players             14382 non-null  object
#  9   rating                     15902 non-null  object
#  10  user_positive_normelize    17814 non-null  float64
#  11  critic_positive_normelize  17814 non-null  float64
# dtypes: float64(4), object(8)
# memory usage: 2.3+ MB

# %% [markdown]
# --------------

# %% [markdown]
# # Adding 'max_players' and 'online_game' columns
# With the information in the 'num_of_players' column

# %%
num_of_players_unique = list(df["num_of_players"].unique())

replace_map_for_max_players = {}
replace_map_for_online_game = {}

for val in num_of_players_unique:
    if(type(val) != float):
        max_player = np.nan
        max_player_list = [int(s) for s in re.findall(r'\b\d+\b', val)]
        if(max_player_list):
            max_player = max(max_player_list)
            replace_map_for_max_players[val] = max_player
        else:
            replace_map_for_max_players[val] = 0

        
        online = ('Online' in val) and ('No Online' not in val)
        if(max_player != np.nan):
            if(max_player >= 4):
                online = True
        
        if(online):
            replace_map_for_online_game[val] = 1
        else:
            replace_map_for_online_game[val] = 0
            
    else:
        replace_map_for_max_players[val] = 0
        replace_map_for_online_game[val] = 0
            
df["max_players"] = df["num_of_players"].copy()
df["online_game"] = df["num_of_players"].copy()

df["max_players"].replace(replace_map_for_max_players, inplace=True)
df["online_game"].replace(replace_map_for_online_game, inplace=True)

df.drop("num_of_players", axis=1, inplace=True)

# %% [markdown]
# ### 'online_game' column:
#
# 1 = online
#
# 0 = not online

# %%
df["online_game"].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ### 'max_players' column:
#
# Maximum players possible in a game

# %%
df["max_players"].unique()
# Out:
# array([ 1,  2,  0, 32, 30, 16,  4,  6,  8, 18, 10, 40, 12,  5, 64, 20, 24,
#        22, 60,  3,  9, 44, 14, 15, 36], dtype=int64)

# %% [markdown]
# --------------
# Checking the data:

# %%
df.head()
# Out:
#                               game_name       platform       publisher  \
# 0  The Legend of Zelda: Ocarina of Time    Nintendo 64        Nintendo
# 1              Tony Hawk's Pro Skater 2    PlayStation      Activision
# 2                   Grand Theft Auto IV  PlayStation 3  Rockstar Games
# 3                           SoulCalibur      Dreamcast           Namco
# 4                   Grand Theft Auto IV       Xbox 360  Rockstar Games
#
#    release_date  meta_scroe  user_score               develeoper  \
# 0  Nov 23, 1998        99.0         9.1                 Nintendo
# 1  Sep 20, 2000        98.0         7.5  Neversoft Entertainment
# 2  Apr 29, 2008        98.0         7.8           Rockstar North
# 3  Sep  8, 1999        98.0         8.4                    Namco
# 4  Apr 29, 2008        98.0         8.0           Rockstar North
#
#                                          genres rating  \
# 0                     Action Adventure, Fantasy      E
# 1            Sports, Alternative, Skateboarding      T
# 2  Action Adventure, Modern, Modern, Open-World      M
# 3                          Action, Fighting, 3D      T
# 4  Action Adventure, Modern, Modern, Open-World      M
#
#    user_positive_normelize  critic_positive_normelize  max_players  \
# 0                 0.893962                        1.0            1
# 1                 0.699196                        1.0            2
# 2                 0.714730                        1.0            1
# 3                 0.825123                        1.0            2
# 4                 0.727593                        1.0            1
#
#    online_game
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17814 entries, 0 to 19222
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   game_name                  17814 non-null  object
#  1   platform                   17814 non-null  object
#  2   publisher                  17814 non-null  object
#  3   release_date               17814 non-null  object
#  4   meta_scroe                 17814 non-null  float64
#  5   user_score                 17814 non-null  float64
#  6   develeoper                 17814 non-null  object
#  7   genres                     17814 non-null  object
#  8   rating                     15902 non-null  object
#  9   user_positive_normelize    17814 non-null  float64
#  10  critic_positive_normelize  17814 non-null  float64
#  11  max_players                17814 non-null  int64
#  12  online_game                17814 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 2.4+ MB

# %% [markdown]
# --------------

# %% [markdown]
# ## We will change the names of the platforms to make them more general

# %%
df["platform"].unique()
# Out:
# array(['Nintendo 64', 'PlayStation', 'PlayStation 3', 'Dreamcast',
#        'Xbox 360', 'Wii', 'Xbox One', 'PC', 'Switch', 'PlayStation 2',
#        'PlayStation 4', 'GameCube', 'Xbox', 'Wii U', 'Xbox Series X',
#        'PlayStation 5', 'Game Boy Advance', '3DS', 'DS',
#        'PlayStation Vita', 'PSP', 'Stadia'], dtype=object)

# %%
platform_replace_map = {
    'PSP': 'PlayStation',
    '3DS': 'Nintendo',
    'Switch': 'Nintendo',
    'DS': 'Nintendo',
    'Game Boy Advance': 'Nintendo',
    'Dreamcast': 'Old Platform',
    'GameCube': 'Old Platform',
    'Nintendo 64': 'Nintendo',
    'Stadia': 'PC'
}
platform_unique_list = list(df["platform"].unique())
for val in platform_unique_list:
    replaceXbox = re.findall(r'(Xbox) ', val)
    replacePlayStation = re.findall(r'(PlayStation) ', val)
    replaceWii = re.findall(r'(Wii) ', val)
    if(replaceXbox):
        platform_replace_map[val] = replaceXbox[0]
    if(replacePlayStation):
        platform_replace_map[val] = replacePlayStation[0]
    if(replaceWii):
        platform_replace_map[val] = replaceWii[0]

df["platform"].replace(platform_replace_map, inplace=True)

# %%
df["platform"].unique()
# Out:
# array(['Nintendo', 'PlayStation', 'Old Platform', 'Xbox', 'Wii', 'PC'],
#       dtype=object)

# %% [markdown]
# ## We will assign to each rating a value related to the order of the rating

# %%
df["rating"].unique()
# Out:
# array(['E', 'T', 'M', 'E10+', nan, 'K-A', 'AO', 'RP'], dtype=object)

# %% [markdown]
# First we replace the nan valuse with the top value:

# %%
top_val = df["rating"].describe()[2]
df["rating"].fillna(top_val, inplace=True)

# %% [markdown]
# The values will be distributed like this:
# - RP - Rating Pending == 0
# - E - Everyone 6 and older == 1
# - E10+ - 10 and older == 2
# - K-A - 10 and older == 2
# - T - Teen 13 and older == 3
# - m - 17+ == 4
# - AO - Adults Only 18 years and older == 5

# %%
rating_replace_map = {
    'RP': 0, 'E': 1, 'E10+': 2,
    'K-A': 2, 'T': 3, 'M': 4, 'AO': 5}

df["rating"].replace(rating_replace_map, inplace=True)

# %% [markdown]
# ## Scaling the 'meta_scroe' and 'user_score' columns

# %%
min_max_scaler = preprocessing.MinMaxScaler()
meta_scroe_scaled = min_max_scaler.fit_transform(df[['meta_scroe']])
user_score_scaled = min_max_scaler.fit_transform(df[['user_score']])
df['meta_score'] = meta_scroe_scaled
df['user_score'] = user_score_scaled
df.drop("meta_scroe", axis=1, inplace=True)

# %% [markdown]
# ## The 'release_date' will be divided into two columns: 'release_month' and 'release_year'

# %%
df["release_date"].unique()
# Out:
# array(['Nov 23, 1998', 'Sep 20, 2000', 'Apr 29, 2008', ...,
#        'Apr 25, 2001', 'Jul  6, 2006', 'Dec 21, 2011'], dtype=object)

# %%
import calendar

# %%
# Getting months by their numbers
month_number = {}
for index, month in enumerate(calendar.month_abbr):
    if(month):
        month_number[month.lower()] = index

# Divides into two columns:
release_date_list = list(df["release_date"])
release_year = []
release_month = []
for date in release_date_list:
    year = re.findall(r'\b\d+\b', date)[1]
    release_year.append(int(year))
    month = re.findall(r'(\w\w\w) ', date)[0]
    release_month.append(month_number[month.lower()])

df['release_year'] = release_year
df['release_month'] = release_month

# %%
df.drop("release_date", axis=1, inplace=True)

# %% [markdown]
# --------------
# Checking the data:

# %%
df.head()
# Out:
#                               game_name      platform       publisher  \
# 0  The Legend of Zelda: Ocarina of Time      Nintendo        Nintendo
# 1              Tony Hawk's Pro Skater 2   PlayStation      Activision
# 2                   Grand Theft Auto IV   PlayStation  Rockstar Games
# 3                           SoulCalibur  Old Platform           Namco
# 4                   Grand Theft Auto IV          Xbox  Rockstar Games
#
#    user_score               develeoper  \
# 0    0.936170                 Nintendo
# 1    0.765957  Neversoft Entertainment
# 2    0.797872           Rockstar North
# 3    0.861702                    Namco
# 4    0.819149           Rockstar North
#
#                                          genres  rating  \
# 0                     Action Adventure, Fantasy       1
# 1            Sports, Alternative, Skateboarding       3
# 2  Action Adventure, Modern, Modern, Open-World       4
# 3                          Action, Fighting, 3D       3
# 4  Action Adventure, Modern, Modern, Open-World       4
#
#    user_positive_normelize  critic_positive_normelize  max_players  \
# 0                 0.893962                        1.0            1
# 1                 0.699196                        1.0            2
# 2                 0.714730                        1.0            1
# 3                 0.825123                        1.0            2
# 4                 0.727593                        1.0            1
#
#    online_game  meta_score  release_year  release_month
# 0            0    1.000000          1998             11
# 1            0    0.988636          2000              9
# 2            0    0.988636          2008              4
# 3            0    0.988636          1999              9
# 4            0    0.988636          2008              4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17814 entries, 0 to 19222
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   game_name                  17814 non-null  object
#  1   platform                   17814 non-null  object
#  2   publisher                  17814 non-null  object
#  3   user_score                 17814 non-null  float64
#  4   develeoper                 17814 non-null  object
#  5   genres                     17814 non-null  object
#  6   rating                     17814 non-null  int64
#  7   user_positive_normelize    17814 non-null  float64
#  8   critic_positive_normelize  17814 non-null  float64
#  9   max_players                17814 non-null  int64
#  10  online_game                17814 non-null  int64
#  11  meta_score                 17814 non-null  float64
#  12  release_year               17814 non-null  int64
#  13  release_month              17814 non-null  int64
# dtypes: float64(4), int64(5), object(5)
# memory usage: 2.5+ MB

# %% [markdown]
# --------------

# %% [markdown]
# # The genres are listed in long lists

# %%
df["genres"]
# Out:
# 0                                Action Adventure, Fantasy
# 1                       Sports, Alternative, Skateboarding
# 2             Action Adventure, Modern, Modern, Open-World
# 3                                     Action, Fighting, 3D
# 4             Action Adventure, Modern, Modern, Open-World
#                                ...
# 19218                           Sports, Individual, Biking
# 19219    Action Adventure, Adventure, Third-Person, Ope...
# 19220          Driving, Racing, Arcade, Arcade, Automobile
# 19221    Driving, Modern, Racing, Motorcycle, Motocross...
# 19222        Miscellaneous, Party, Party, Party / Minigame
# Name: genres, Length: 17814, dtype: object

# %%
len(df["genres"].unique())
# Out:
# 2184

# %% [markdown]
# ### We will arrange the genres in order to minimize the appearance:

# %%
genres_per_game = []
for game_genres in df["genres"]:
    genre_list = sorted(game_genres.split(", "))
    genres_new_string = ", ".join(genre_list)
    genres_per_game.append(genres_new_string)

df["genres"] = genres_per_game

# %%
len(df["genres"].unique())
# Out:
# 1827

# %% [markdown]
# -------------
# <a id='Improving_Performance2'></a>
# ## <font color='red'>problem2:</font> Handling Duplicates in 'genres' column
# See problem in page: [Problem2: Improving Performance](#Improving_Performance)
#
# We found that there is a duplication problem in the column,
#
# There are genres duplications, and also redundant commas

# %%
test = [val for val in df["genres"].unique() if val.startswith(",")]
test[2]
# Out:
# ', 2D, 2D, Action, Action RPG, Platformer, Platformer, Role-Playing'

# %% [markdown]
# Exexample:

# %%
df["genres"][23]
# Out:
# 'Action, Arcade, First-Person, Sci-Fi, Sci-Fi, Shooter, Shooter'

# %% [markdown]
# Handling Duplicates:

# %%
genres_per_game = []
for game_genres in df["genres"]:
    genre_list = set(game_genres.strip(", ").lower().split(", "))
    genre_list = sorted(list(genre_list))
    genres_new_string = ", ".join(genre_list)
    genres_per_game.append(genres_new_string)
    
df["genres"] = genres_per_game

# %%
len(df["genres"].unique())
# Out:
# 1371

# %%
df["genres"][23]
# Out:
# 'action, arcade, first-person, sci-fi, shooter'

# %% [markdown]
# ----------------
# #### Reordering the dataframe

# %%
columns_order = ["game_name", "platform", "genres",
                 "develeoper", "publisher", "max_players",
                 "online_game", "release_year", "release_month",
                 "rating", "meta_score", "user_score",
                 "critic_positive_normelize", "user_positive_normelize",
                ]
df = df[columns_order]
df.head()
# Out:
#                               game_name      platform  \
# 0  The Legend of Zelda: Ocarina of Time      Nintendo
# 1              Tony Hawk's Pro Skater 2   PlayStation
# 2                   Grand Theft Auto IV   PlayStation
# 3                           SoulCalibur  Old Platform
# 4                   Grand Theft Auto IV          Xbox
#
#                                  genres               develeoper  \
# 0             action adventure, fantasy                 Nintendo
# 1    alternative, skateboarding, sports  Neversoft Entertainment
# 2  action adventure, modern, open-world           Rockstar North
# 3                  3d, action, fighting                    Namco
# 4  action adventure, modern, open-world           Rockstar North
#
#         publisher  max_players  online_game  release_year  release_month  \
# 0        Nintendo            1            0          1998             11
# 1      Activision            2            0          2000              9
# 2  Rockstar Games            1            0          2008              4
# 3           Namco            2            0          1999              9
# 4  Rockstar Games            1            0          2008              4
#
#    rating  meta_score  user_score  critic_positive_normelize  \
# 0       1    1.000000    0.936170                        1.0
# 1       3    0.988636    0.765957                        1.0
# 2       4    0.988636    0.797872                        1.0
# 3       3    0.988636    0.861702                        1.0
# 4       4    0.988636    0.819149                        1.0
#
#    user_positive_normelize
# 0                 0.893962
# 1                 0.699196
# 2                 0.714730
# 3                 0.825123
# 4                 0.727593

# %% [markdown]
# ----------------

# %% [markdown]
# ## We have meny duplicates in the 'game_name' column

# %%
df[df["game_name"] == "Assassin's Creed Origins"]
# Out:
#                      game_name     platform  \
# 1674  Assassin's Creed Origins           PC
# 3227  Assassin's Creed Origins  PlayStation
#
#                                                  genres develeoper publisher  \
# 1674  action adventure, edutainment, miscellaneous, ...    Ubisoft   Ubisoft
# 3227  action adventure, edutainment, miscellaneous, ...    Ubisoft   Ubisoft
#
#       max_players  online_game  release_year  release_month  rating  \
# 1674            0            0          2017             10       4
# 3227            0            0          2017             10       4
#
#       meta_score  user_score  critic_positive_normelize  \
# 1674    0.829545    0.702128                   0.896552
# 3227    0.795455    0.744681                   0.841270
#
#       user_positive_normelize
# 1674                 0.584201
# 3227                 0.640732

# %% [markdown]
# ------------------

# %% [markdown]
# ## Handling duplicates in 'game_name'

# %%
duplicates = df[df["game_name"].duplicated(keep=False)].copy()
duplicates_names = list(duplicates["game_name"].unique())
df.reset_index(drop=True, inplace=True)

for duplicate_name in duplicates_names:
    duplicates_game = df[df["game_name"] == duplicate_name]
    
    # saving the mean valu of the duplicates
    meta_score_mean = duplicates_game["meta_score"].mean()
    user_score_mean = duplicates_game["user_score"].mean()
    critic_mean = duplicates_game["critic_positive_normelize"].mean()
    user_mean = duplicates_game["user_positive_normelize"].mean()
    
    row_index = df[df["game_name"] == duplicate_name].index[0]
    df.loc[row_index, "meta_score"] = meta_score_mean
    df.loc[row_index, "user_score"] = user_score_mean
    df.loc[row_index, "critic_positive_normelize"] = critic_mean
    df.loc[row_index, "user_positive_normelize"] = user_mean
    
    # making a platform string of all the duplicates platforms
    platforms = set()
    for val in duplicates_game["platform"]:
        platforms.add(val)
    # the list will be sorted for future labeling
    platforms = sorted(list(platforms))
    df.loc[row_index, "platform"] = ", ".join(platforms)
    
    # saving the earliest date of the duplicates
    year_month_zip = zip(duplicates_game["release_year"], duplicates_game["release_month"])
    release_year = min(duplicates_game["release_year"])
    release_month = 12
    for year, month in year_month_zip:
        if(year == release_year and month < release_month):
            release_month = month
    df.loc[row_index, "release_year"] = release_year
    df.loc[row_index, "release_month"] = release_month

df = df.drop_duplicates(subset="game_name")
df.reset_index(drop=True, inplace=True)

# %%
len(df["platform"].unique())
# Out:
# 54

# %% [markdown]
# -------------------

# %% [markdown]
# ## Making 'exclusive_game' column:
# Content:
#
# 1 - Games released for only one platform
#
# 0 - Otherwise

# %%
exclusive_games_list = []
for platforms in df["platform"]:
    platforms_list = platforms.split(", ")
    if(len(platforms_list) != 1 or 'Old Platform' in platforms_list):
        exclusive_games_list.append(0)
    else:
        exclusive_games_list.append(1)
df['exclusive_game'] = exclusive_games_list

# %% [markdown]
# After Duplication Handling

# %%
df[df["game_name"] == "Assassin's Creed Origins"]
# Out:
#                      game_name         platform  \
# 1223  Assassin's Creed Origins  PC, PlayStation
#
#                                                  genres develeoper publisher  \
# 1223  action adventure, edutainment, miscellaneous, ...    Ubisoft   Ubisoft
#
#       max_players  online_game  release_year  release_month  rating  \
# 1223            0            0          2017             10       4
#
#       meta_score  user_score  critic_positive_normelize  \
# 1223      0.8125    0.723404                   0.868911
#
#       user_positive_normelize  exclusive_game
# 1223                 0.612466               0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11695 entries, 0 to 11694
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   game_name                  11695 non-null  object
#  1   platform                   11695 non-null  object
#  2   genres                     11695 non-null  object
#  3   develeoper                 11695 non-null  object
#  4   publisher                  11695 non-null  object
#  5   max_players                11695 non-null  int64
#  6   online_game                11695 non-null  int64
#  7   release_year               11695 non-null  int64
#  8   release_month              11695 non-null  int64
#  9   rating                     11695 non-null  int64
#  10  meta_score                 11695 non-null  float64
#  11  user_score                 11695 non-null  float64
#  12  critic_positive_normelize  11695 non-null  float64
#  13  user_positive_normelize    11695 non-null  float64
#  14  exclusive_game             11695 non-null  int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 1.3+ MB

# %% [markdown]
# ---------------

# %% [markdown]
# ## Labeling the 'publisher', 'develeoper', 'genres', 'main_genre' and 'platform' columns

# %%
df["publisher_labeled"] = LabelEncoder().fit_transform(df["publisher"])
df["develeoper_labeled"] = LabelEncoder().fit_transform(df["develeoper"])
df["genres_labeled"] = LabelEncoder().fit_transform(df["genres"])
df["platform_labeled"] = LabelEncoder().fit_transform(df["platform"])

# %%
df
# Out:
#                                           game_name  \
# 0              The Legend of Zelda: Ocarina of Time
# 1                          Tony Hawk's Pro Skater 2
# 2                               Grand Theft Auto IV
# 3                                       SoulCalibur
# 4                                Super Mario Galaxy
# ...                                             ...
# 11690                                  SPOGS Racing
# 11691       Double Dragon II: Wander of the Dragons
# 11692                        Vroom in the Night Sky
# 11693                                         Yaris
# 11694  Family Party: 30 Great Games Obstacle Arcade
#
#                                       platform  \
# 0                                     Nintendo
# 1      Nintendo, Old Platform, PC, PlayStation
# 2                        PC, PlayStation, Xbox
# 3                           Old Platform, Xbox
# 4                                          Wii
# ...                                        ...
# 11690                                      Wii
# 11691                                     Xbox
# 11692                                 Nintendo
# 11693                                     Xbox
# 11694                                      Wii
#
#                                        genres               develeoper  \
# 0                   action adventure, fantasy                 Nintendo
# 1          alternative, skateboarding, sports  Neversoft Entertainment
# 2        action adventure, modern, open-world           Rockstar North
# 3                        3d, action, fighting                    Namco
# 4                      3d, action, platformer                 Nintendo
# ...                                       ...                      ...
# 11690     arcade, automobile, driving, racing             Pronto Games
# 11691                 2d, action, beat-'em-up      Gravity Corporation
# 11692              biking, individual, sports                  Poisoft
# 11693     arcade, automobile, driving, racing   Backbone Entertainment
# 11694  miscellaneous, party, party / minigame            Art Co., Ltd.
#
#                     publisher  max_players  online_game  release_year  \
# 0                    Nintendo            1            0          1998
# 1                  Activision            2            0          2000
# 2              Rockstar Games            1            0          2008
# 3                       Namco            2            0          1999
# 4                    Nintendo            0            0          2007
# ...                       ...          ...          ...           ...
# 11690               D2C Games            0            0          2008
# 11691                     CFK            0            0          2013
# 11692                 Poisoft            0            0          2017
# 11693  Backbone Entertainment            2            1          2007
# 11694             D3Publisher            0            0          2012
#
#        release_month  rating  meta_score  user_score  \
# 0                 11       1    1.000000    0.936170
# 1                  9       3    0.931818    0.765957
# 2                  4       4    0.958333    0.780142
# 3                  9       3    0.880682    0.829787
# 4                 11       1    0.977273    0.936170
# ...              ...     ...         ...         ...
# 11690              7       1    0.079545    0.361702
# 11691              4       3    0.068182    0.138298
# 11692              4       1    0.068182    0.319149
# 11693             10       2    0.068182    0.436170
# 11694             12       1    0.000000    0.255319
#
#        critic_positive_normelize  user_positive_normelize  exclusive_game  \
# 0                       1.000000                 0.893962               1
# 1                       0.970909                 0.717737               0
# 2                       0.983333                 0.681603               0
# 3                       0.947368                 0.725062               0
# 4                       1.000000                 0.911193               1
# ...                          ...                      ...             ...
# 11690                   0.000000                 0.363636               1
# 11691                   0.000000                 0.135593               1
# 11692                   0.000000                 0.284404               1
# 11693                   0.000000                 0.389706               1
# 11694                   0.000000                 0.255102               1
#
#        publisher_labeled  develeoper_labeled  genres_labeled  platform_labeled
# 0                   1070                2078             262                 0
# 1                     59                2045             805                 3
# 2                   1323                2572             323                43
# 3                   1042                2013             143                38
# 4                   1070                2078             154                51
# ...                  ...                 ...             ...               ...
# 11690                373                2380             834                51
# 11691                256                1258              33                53
# 11692               1221                2346             910                 0
# 11693                143                 277             834                53
# 11694                376                 203            1250                51
#
# [11695 rows x 19 columns]

# %% [markdown]
# ----------------
# #### Reordering the dataframe

# %%
columns_order = ["game_name", "platform", "genres",
                 "develeoper", "publisher", "max_players",
                 "online_game", "release_year", "release_month",
                 "rating", "meta_score", "user_score",
                 "critic_positive_normelize", "user_positive_normelize",
                 "exclusive_game", "publisher_labeled", "develeoper_labeled",
                 "genres_labeled", "platform_labeled",
                ]
df = df[columns_order]

# %% [markdown]
# # Final result

# %%
df.head()
# Out:
#                               game_name  \
# 0  The Legend of Zelda: Ocarina of Time
# 1              Tony Hawk's Pro Skater 2
# 2                   Grand Theft Auto IV
# 3                           SoulCalibur
# 4                    Super Mario Galaxy
#
#                                   platform  \
# 0                                 Nintendo
# 1  Nintendo, Old Platform, PC, PlayStation
# 2                    PC, PlayStation, Xbox
# 3                       Old Platform, Xbox
# 4                                      Wii
#
#                                  genres               develeoper  \
# 0             action adventure, fantasy                 Nintendo
# 1    alternative, skateboarding, sports  Neversoft Entertainment
# 2  action adventure, modern, open-world           Rockstar North
# 3                  3d, action, fighting                    Namco
# 4                3d, action, platformer                 Nintendo
#
#         publisher  max_players  online_game  release_year  release_month  \
# 0        Nintendo            1            0          1998             11
# 1      Activision            2            0          2000              9
# 2  Rockstar Games            1            0          2008              4
# 3           Namco            2            0          1999              9
# 4        Nintendo            0            0          2007             11
#
#    rating  meta_score  user_score  critic_positive_normelize  \
# 0       1    1.000000    0.936170                   1.000000
# 1       3    0.931818    0.765957                   0.970909
# 2       4    0.958333    0.780142                   0.983333
# 3       3    0.880682    0.829787                   0.947368
# 4       1    0.977273    0.936170                   1.000000
#
#    user_positive_normelize  exclusive_game  publisher_labeled  \
# 0                 0.893962               1               1070
# 1                 0.717737               0                 59
# 2                 0.681603               0               1323
# 3                 0.725062               0               1042
# 4                 0.911193               1               1070
#
#    develeoper_labeled  genres_labeled  platform_labeled
# 0                2078             262                 0
# 1                2045             805                 3
# 2                2572             323                43
# 3                2013             143                38
# 4                2078             154                51

# %%
df.iloc[:, 5:]
# Out:
#        max_players  online_game  release_year  release_month  rating  \
# 0                1            0          1998             11       1
# 1                2            0          2000              9       3
# 2                1            0          2008              4       4
# 3                2            0          1999              9       3
# 4                0            0          2007             11       1
# ...            ...          ...           ...            ...     ...
# 11690            0            0          2008              7       1
# 11691            0            0          2013              4       3
# 11692            0            0          2017              4       1
# 11693            2            1          2007             10       2
# 11694            0            0          2012             12       1
#
#        meta_score  user_score  critic_positive_normelize  \
# 0        1.000000    0.936170                   1.000000
# 1        0.931818    0.765957                   0.970909
# 2        0.958333    0.780142                   0.983333
# 3        0.880682    0.829787                   0.947368
# 4        0.977273    0.936170                   1.000000
# ...           ...         ...                        ...
# 11690    0.079545    0.361702                   0.000000
# 11691    0.068182    0.138298                   0.000000
# 11692    0.068182    0.319149                   0.000000
# 11693    0.068182    0.436170                   0.000000
# 11694    0.000000    0.255319                   0.000000
#
#        user_positive_normelize  exclusive_game  publisher_labeled  \
# 0                     0.893962               1               1070
# 1                     0.717737               0                 59
# 2                     0.681603               0               1323
# 3                     0.725062               0               1042
# 4                     0.911193               1               1070
# ...                        ...             ...                ...
# 11690                 0.363636               1                373
# 11691                 0.135593               1                256
# 11692                 0.284404               1               1221
# 11693                 0.389706               1                143
# 11694                 0.255102               1                376
#
#        develeoper_labeled  genres_labeled  platform_labeled
# 0                    2078             262                 0
# 1                    2045             805                 3
# 2                    2572             323                43
# 3                    2013             143                38
# 4                    2078             154                51
# ...                   ...             ...               ...
# 11690                2380             834                51
# 11691                1258              33                53
# 11692                2346             910                 0
# 11693                 277             834                53
# 11694                 203            1250                51
#
# [11695 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11695 entries, 0 to 11694
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   game_name                  11695 non-null  object
#  1   platform                   11695 non-null  object
#  2   genres                     11695 non-null  object
#  3   develeoper                 11695 non-null  object
#  4   publisher                  11695 non-null  object
#  5   max_players                11695 non-null  int64
#  6   online_game                11695 non-null  int64
#  7   release_year               11695 non-null  int64
#  8   release_month              11695 non-null  int64
#  9   rating                     11695 non-null  int64
#  10  meta_score                 11695 non-null  float64
#  11  user_score                 11695 non-null  float64
#  12  critic_positive_normelize  11695 non-null  float64
#  13  user_positive_normelize    11695 non-null  float64
#  14  exclusive_game             11695 non-null  int64
#  15  publisher_labeled          11695 non-null  int32
#  16  develeoper_labeled         11695 non-null  int32
#  17  genres_labeled             11695 non-null  int32
#  18  platform_labeled           11695 non-null  int32
# dtypes: float64(4), int32(4), int64(6), object(5)
# memory usage: 1.5+ MB

# %%
df.describe(include="all")
# Out:
#                                    game_name platform                  genres  \
# count                                  11695    11695                   11695
# unique                                 11695       54                    1296
# top     The Legend of Zelda: Ocarina of Time       PC  2d, action, platformer
# freq                                       1     2710                     476
# mean                                     NaN      NaN                     NaN
# std                                      NaN      NaN                     NaN
# min                                      NaN      NaN                     NaN
# 25%                                      NaN      NaN                     NaN
# 50%                                      NaN      NaN                     NaN
# 75%                                      NaN      NaN                     NaN
# max                                      NaN      NaN                     NaN
#
#        develeoper publisher   max_players   online_game  release_year  \
# count       11695     11695  11695.000000  11695.000000  11695.000000
# unique       3575      1819           NaN           NaN           NaN
# top        Capcom  Nintendo           NaN           NaN           NaN
# freq          192       563           NaN           NaN           NaN
# mean          NaN       NaN      2.459855      0.259000   2011.186575
# std           NaN       NaN      6.249083      0.438104      6.401113
# min           NaN       NaN      0.000000      0.000000   1996.000000
# 25%           NaN       NaN      0.000000      0.000000   2006.000000
# 50%           NaN       NaN      0.000000      0.000000   2011.000000
# 75%           NaN       NaN      2.000000      1.000000   2017.000000
# max           NaN       NaN     64.000000      1.000000   2023.000000
#
#         release_month        rating    meta_score    user_score  \
# count    11695.000000  11695.000000  11695.000000  11695.000000
# unique            NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN
# mean         6.972980      2.529372      0.670451      0.708804
# std          3.345524      1.056537      0.138328      0.140259
# min          1.000000      0.000000      0.000000      0.000000
# 25%          4.000000      1.000000      0.594223      0.638298
# 50%          7.000000      3.000000      0.693182      0.739362
# 75%         10.000000      3.000000      0.768939      0.808511
# max         12.000000      5.000000      1.000000      1.000000
#
#         critic_positive_normelize  user_positive_normelize  exclusive_game  \
# count                11695.000000             11695.000000    11695.000000
# unique                        NaN                      NaN             NaN
# top                           NaN                      NaN             NaN
# freq                          NaN                      NaN             NaN
# mean                     0.481108                 0.590597        0.677555
# std                      0.309747                 0.185361        0.467432
# min                      0.000000                 0.000000        0.000000
# 25%                      0.200000                 0.473684        0.000000
# 50%                      0.482517                 0.619023        1.000000
# 75%                      0.750000                 0.731707        1.000000
# max                      1.000000                 1.000000        1.000000
#
#         publisher_labeled  develeoper_labeled  genres_labeled  \
# count        11695.000000        11695.000000    11695.000000
# unique                NaN                 NaN             NaN
# top                   NaN                 NaN             NaN
# freq                  NaN                 NaN             NaN
# mean           904.794699         1774.533048      666.640445
# std            533.328536         1027.786135      391.251545
# min              0.000000            0.000000        0.000000
# 25%            456.000000          903.000000      322.000000
# 50%            964.000000         1759.000000      685.000000
# 75%           1373.000000         2685.000000     1042.000000
# max           1818.000000         3574.000000     1295.000000
#
#         platform_labeled
# count        11695.00000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean            35.26832
# std             17.31440
# min              0.00000
# 25%             29.00000
# 50%             39.00000
# 75%             47.00000
# max             53.00000

# %% [markdown]
# ## Saving data in 'all_games.csv' file

# %%
# df.to_csv(f'games_data/lowest_top_merge.csv')

# %% [markdown]
# <a id='Incomplete_data'></a>
# ## Saving data in 'handled_games.csv' file
# ### Added after <font color='red'>Problem1:</font> Incomplete data

# %%
# df.to_csv(f'games_data/handled_games.csv')

# %% [markdown]
# <a id='Improving_Performance4'></a>
# ## Saving data in 'handled_games2.csv' file
# ### Added after <font color='red'>Problem2:</font> Improving Performance

# %%
df.to_csv(f'games_data/handled_games2.csv')

# %% [markdown]
# After saving the file we moved to the next step: EDA
#
# see next step: [4_EDA](./4_EDA.ipynb)

# %% [markdown]
# -------------------
