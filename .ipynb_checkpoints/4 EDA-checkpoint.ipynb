# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("games_data/all_games.csv")

# %%
# Deletion of the index column - "Unnamed: 0"
df.drop("Unnamed: 0", axis=1, inplace=True)
df.head()
# Out:
#                        game_name      platform     main_genre  \
# 0                        Tharsis  Nintendo, PC  Miscellaneous
# 1  WWI Tannenberg: Eastern Front   PlayStation         Action
# 2                     Dungeons 2   PlayStation        General
# 3                  WE ARE DOOMED   PlayStation         Action
# 4     Sixty Second Shooter Prime          Xbox         Action
#
#              develeoper             publisher  max_players  online_game  \
# 0     Choice Provisions     Choice Provisions            1            0
# 1                   M2H       Blackmill Games           40            1
# 2               Kalypso               Kalypso            4            1
# 3            Vertex Pop            Vertex Pop            1            0
# 4  Happion Laboratories  Happion Laboratories            1            0
#
#    release_year  release_month  rating  meta_score  user_score  \
# 0          2016              1       4    0.551136    0.589962
# 1          2020              7       4    0.568182    0.851064
# 2          2016              5       3    0.568182    0.670213
# 3          2015              4       1    0.568182    0.595745
# 4          2014              6       1    0.568182    0.723404
#
#    critic_positive_normelize  user_positive_normelize  exclusive_game  \
# 0                   0.127717                 0.420218               0
# 1                   0.300000                 0.061367               1
# 2                   0.111111                 0.182523               1
# 3                   0.222222                 0.124717               1
# 4                   0.000000                 0.124686               1
#
#    publisher_labeled  develeoper_labeled  main_genres_labeled  \
# 0                175                 354                    6
# 1                121                1089                    0
# 2                495                 991                    5
# 3                963                2032                    0
# 4                423                 821                    0
#
#    platform_labeled
# 0                 7
# 1                39
# 2                39
# 3                39
# 4                45

# %%
df.iloc[:, 5:]
# Out:
#       max_players  online_game  release_year  release_month  rating  \
# 0               1            0          2016              1       4
# 1              40            1          2020              7       4
# 2               4            1          2016              5       3
# 3               1            0          2015              4       1
# 4               1            0          2014              6       1
# ...           ...          ...           ...            ...     ...
# 5752            1            0          2021             10       4
# 5753            1            0          2016              9       3
# 5754            1            0          2022              5       4
# 5755            1            0          2019              3       3
# 5756            1            0          2014              3       3
#
#       meta_score  user_score  critic_positive_normelize  \
# 0       0.551136    0.589962                   0.127717
# 1       0.568182    0.851064                   0.300000
# 2       0.568182    0.670213                   0.111111
# 3       0.568182    0.595745                   0.222222
# 4       0.568182    0.723404                   0.000000
# ...          ...         ...                        ...
# 5752    0.795455    0.765957                   1.000000
# 5753    0.795455    0.776596                   0.857143
# 5754    0.795455    0.723404                   0.888889
# 5755    0.795455    0.840426                   0.833333
# 5756    0.795455    0.829787                   0.700000
#
#       user_positive_normelize  exclusive_game  publisher_labeled  \
# 0                    0.420218               0                175
# 1                    0.061367               1                121
# 2                    0.182523               1                495
# 3                    0.124717               1                963
# 4                    0.124686               1                423
# ...                       ...             ...                ...
# 5752                 0.681818               1                209
# 5753                 0.663165               1                764
# 5754                 0.604167               1                350
# 5755                 0.833333               1                632
# 5756                 0.768421               1                791
#
#       develeoper_labeled  main_genres_labeled  platform_labeled
# 0                    354                    6                 7
# 1                   1089                    0                39
# 2                    991                    5                39
# 3                   2032                    0                39
# 4                    821                    0                45
# ...                  ...                  ...               ...
# 5752                 430                    6                45
# 5753                  55                   14                45
# 5754                 391                   14                31
# 5755                1284                    0                 0
# 5756                1641                    0                39
#
# [5757 rows x 14 columns]

# %%
df[["meta_score", "user_score"]].corr()
# Out:
#             meta_score  user_score
# meta_score    1.000000    0.657203
# user_score    0.657203    1.000000

# %%
df[["critic_positive_normelize", "user_positive_normelize"]].corr()
# Out:
#                            critic_positive_normelize  user_positive_normelize
# critic_positive_normelize                   1.000000                 0.834681
# user_positive_normelize                     0.834681                 1.000000

# %%
sns.scatterplot(data=df, x="user_score", y="meta_score")
# Out:
# <AxesSubplot:xlabel='user_score', ylabel='meta_score'>

# %%
len(df[df["user_score"] > 0.73])
# Out:
# 2801

# %%
len(df[df["user_score"] <= 0.73])
# Out:
# 2956

# %%
df.meta_score.hist(bins=30)
plt.xlabel('meta_score')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.user_score.hist(bins=30)
plt.xlabel('user_score')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Combining the data files into one data frame
file_name1 = "games_data/lowest_rated_games.csv"
file_name2 = "games_data/top_rated_games.csv"
df = pd.concat(
    map(pd.read_csv, [file_name1, file_name2]), ignore_index=True)

# %%
df.meta_scroe.hist(bins=50)
plt.xlabel('meta_scroe')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
62 - 80

# %%
sns.kdeplot(df.user_score, shade=True)
# Out:
# <AxesSubplot:xlabel='user_score', ylabel='Density'>

# %%
sns.kdeplot(df.meta_score, shade=True)
# Out:
# <AxesSubplot:xlabel='meta_score', ylabel='Density'>

# %%
df[df["exclusive_game"] == 1]["platform"].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='platform'>

# %%
df[df["exclusive_game"] == 0]["platform"].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(10,10), )
# Out:
# <AxesSubplot:ylabel='platform'>
